# %% [markdown]
# <a href="https://colab.research.google.com/github/DPxFALCON/Drone-AI-Roof-Inspection/blob/main/Drone_AI_Roof_Inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required library
# !pip install opencv-python-headless

import cv2
import numpy as np
from IPython.display import display
from PIL import Image
import urllib.request

# Download a sample roof image (for testing)
urllib.request.urlretrieve(
    "https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/280px-PNG_transparency_demonstration_1.png",
    "test.png"
)

# Load and process
img = cv2.imread("test.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 100, 200)

# Show result
display(Image.fromarray(edges))
print("Edge detection complete!")
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_283/1922706453.py in <cell line: 0>()
#       9
#      10 # Download a sample roof image (for testing)
# ---> 11 urllib.request.urlretrieve(
#      12     "https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/280px-PNG_transparency_demonstration_1.png",
#      13     "test.png"
#
# /usr/lib/python3.12/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     238     url_type, path = _splittype(url)
#     239
# --> 240     with contextlib.closing(urlopen(url, data)) as fp:
#     241         headers = fp.info()
#     242
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
# ...

# %%
import cv2
import numpy as np
from IPython.display import display
from PIL import Image

# Create a fake "roof" image to test on
img = np.zeros((400, 600), dtype=np.uint8)

# Draw some fake cracks (lines)
cv2.line(img, (100, 100), (300, 150), 255, 2)
cv2.line(img, (200, 200), (450, 280), 255, 3)
cv2.line(img, (50, 300), (200, 350), 255, 2)

# Add some noise to make it realistic
noise = np.random.randint(0, 30, img.shape, dtype=np.uint8)
img = cv2.add(img, noise)

# Apply edge detection
edges = cv2.Canny(img, 50, 150)

# Show both images side by side
combined = np.hstack([img, edges])
display(Image.fromarray(combined))

print("Left = Original | Right = Detected edges")
print("Crack detection working!")
# Out:
# <PIL.Image.Image image mode=L size=1200x400>
# Left = Original | Right = Detected edges
# Crack detection working!
